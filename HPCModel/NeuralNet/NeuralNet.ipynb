# %%
import tensorflow as tf
import numpy as np
import random
import matplotlib.pyplot as plt

from numpy import genfromtxt




# # convert ndarray to tensor
# def my_func(arg):
#   arg = tf.convert_to_tensor(arg, dtype=tf.float32)
# #   sess=tf.InteractiveSession()
# #   print arg.eval()
#   return arg

# Load in training and testing data
# Shape of (record_num, col_num): (999,7)
my_data = genfromtxt('Data/s10_s23_train_data.csv', delimiter=',')
my_testing = genfromtxt('Data/s10_s23_test_data.csv', delimiter=',')

category = 10

factor = 5

# %%
# batch function
def my_batch(category,num,my_data):
#     choose a num of batch return x, y as vectors
    size,col = my_data.shape
    idList = random.sample(range(0, size), num )
    batch_xs = np.zeros(shape=(num,col-category))
    batch_ys = np.zeros(shape=(num,category))
    
    for index,i in enumerate(idList):
        line = my_data[i,:-category]
        batch_xs[index]=line
        label = my_data[i,col-category:col]
        batch_ys[index]=label
    return batch_xs,batch_ys
    
def testingDataLoader(category,my_data):
    size,col = my_data.shape
    
    batch_xs = np.zeros(shape=(size,col-category))
    batch_ys = np.zeros(shape=(size,category))
    for index,line in enumerate(my_data):
        batch_xs[index]=line[:-category]
        batch_ys[index]=line[col-category:col]

        
    return batch_xs,batch_ys

# %%
# Implementation starts!

# None means any number, so x is not a specific number here.
x = tf.placeholder(tf.float32, [None, factor],name="x-input")


# In[16]:

# Init weights, bias, (all zeros first) and define softmax function
W = tf.Variable(tf.zeros([factor, category]),name="weights")
b = tf.Variable(tf.zeros([category],name="bias"))

# use a name scope to organize nodes in the graph visualizer
with tf.name_scope("Wx_b") as scope:
# first multiply x and w, then add b vector. apply softmax to get probabilities
  y = tf.nn.softmax(tf.matmul(x, W) + b)
#     y = tf.matmul(x, W) + b
print "y",type(y)

# Add summary ops to collect data
w_hist = tf.histogram_summary("weights", W)
b_hist = tf.histogram_summary("biases", b)
y_hist = tf.histogram_summary("y", y)


weights_summary = tf.histogram_summary("weights", W)
biases_summary = tf.histogram_summary("biases", b)
y_summary = tf.histogram_summary("y", y)


# In[20]:

# Trainning
y_ = tf.placeholder(tf.float32, [None, category],name="y-input")

with tf.name_scope("xent") as scope:
# tf.log computes logarithm of each element. 
#   cross_entropy = -tf.reduce_sum(y_*tf.log(y))
    gap = tf.sub(y,y_)
    cross_entropy = tf.reduce_sum(tf.square(gap))
with tf.name_scope("train") as scope:
# minimize cross_entropy using the gradient descent algorithm with a learning rate of 0.01. 
  train_step = tf.train.GradientDescentOptimizer(0.001).minimize(cross_entropy)


# In[21]:
# Out:
# y <class 'tensorflow.python.framework.ops.Tensor'>

# %%
# In[22]:

with tf.name_scope("test") as scope:
# evaluation
  correct_prediction = tf.equal(tf.argmax(y,1), tf.argmax(y_,1))
  accuracy = tf.reduce_mean(tf.cast(correct_prediction, "float"))
#   accuracy = cross_entropy
  accuracy_summary = tf.scalar_summary("accuracy", accuracy)

  
  
init = tf.initialize_all_variables()

# launch the model in a Session, run the initialized operation
sess = tf.Session()
sess.run(init)


  
# Merge all the summaries and write them out to /tmp/mnist_logs
merged = tf.merge_summary([weights_summary, biases_summary, y_summary])
writer = tf.train.SummaryWriter("/tmp/read2", sess.graph_def)
tf.train.SummaryWriter("/tmp/read2", sess.graph_def).flush()
# tf.train.SummaryWriter.flush()

# %%
# get testing data
test_xs,test_ys = testingDataLoader(category,my_testing)


# Train for 1000 times!
# batch of 100 at each time
# train_step feeding in the batches data to replace the placeholders
for i in range(10000):


  batch_xs, batch_ys = my_batch(category,100, my_data)
  feed = {x: batch_xs, y_: batch_ys}

  if i%100 == 0:
    train_accuracy = accuracy.eval(session=sess, feed_dict=feed)
    print "type ",tf.shape(accuracy)
    print "value ", accuracy
    print "step %d, training accuracy %g"%(i, train_accuracy)
  train_step.run(session=sess, feed_dict=feed)


#     batch_xs, batch_ys = my_batch(category,100, my_data)
#     feed = {x: batch_xs, y_: batch_ys}
#     sess.run(train_step, feed_dict=feed)
# Out:
# type  Tensor("Shape_617:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  Tensor("test_6/Mean:0", shape=TensorShape([]), dtype=float32)
# step 0, training accuracy 0.89
# type  Tensor("Shape_618:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  Tensor("test_6/Mean:0", shape=TensorShape([]), dtype=float32)
# step 100, training accuracy 0.89
# type  Tensor("Shape_619:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  Tensor("test_6/Mean:0", shape=TensorShape([]), dtype=float32)
# step 200, training accuracy 0.91
# type  Tensor("Shape_620:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  Tensor("test_6/Mean:0", shape=TensorShape([]), dtype=float32)
# step 300, training accuracy 0.87
# type  Tensor("Shape_621:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  Tensor("test_6/Mean:0", shape=TensorShape([]), dtype=float32)
# step 400, training accuracy 0.83
# type  Tensor("Shape_622:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  Tensor("test_6/Mean:0", shape=TensorShape([]), dtype=float32)
# step 500, training accuracy 0.84
# type  Tensor("Shape_623:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  Tensor("test_6/Mean:0", shape=TensorShape([]), dtype=float32)
# step 600, training accuracy 0.84
# type  Tensor("Shape_624:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  Tensor("test_6/Mean:0", shape=TensorShape([]), dtype=float32)
# step 700, training accuracy 0.88
# type  Tensor("Shape_625:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  Tensor("test_6/Mean:0", shape=TensorShape([]), dtype=float32)
# step 800, training accuracy 0.87
# type  Tensor("Shape_626:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  Tensor("test_6/Mean:0", shape=TensorShape([]), dtype=float32)
# step 900, training accuracy 0.87
# type  Tensor("Shape_627:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  Tensor("test_6/Mean:0", shape=TensorShape([]), dtype=float32)
# step 1000, training accuracy 0.82
# type  Tensor("Shape_628:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  Tensor("test_6/Mean:0", shape=TensorShape([]), dtype=float32)
# step 1100, training accuracy 0.87
# type  Tensor("Shape_629:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  Tensor("test_6/Mean:0", shape=TensorShape([]), dtype=float32)
# step 1200, training accuracy 0.85
# type  Tensor("Shape_630:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  Tensor("test_6/Mean:0", shape=TensorShape([]), dtype=float32)
# step 1300, training accuracy 0.84
# type  Tensor("Shape_631:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  Tensor("test_6/Mean:0", shape=TensorShape([]), dtype=float32)
# step 1400, training accuracy 0.86
# type  Tensor("Shape_632:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  Tensor("test_6/Mean:0", shape=TensorShape([]), dtype=float32)
# step 1500, training accuracy 0.86
# type  Tensor("Shape_633:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  Tensor("test_6/Mean:0", shape=TensorShape([]), dtype=float32)
# step 1600, training accuracy 0.85
# type  Tensor("Shape_634:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  Tensor("test_6/Mean:0", shape=TensorShape([]), dtype=float32)
# step 1700, training accuracy 0.84
# type  Tensor("Shape_635:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  Tensor("test_6/Mean:0", shape=TensorShape([]), dtype=float32)
# step 1800, training accuracy 0.87
# type  Tensor("Shape_636:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  Tensor("test_6/Mean:0", shape=TensorShape([]), dtype=float32)
# step 1900, training accuracy 0.82
# type  Tensor("Shape_637:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  Tensor("test_6/Mean:0", shape=TensorShape([]), dtype=float32)
# step 2000, training accuracy 0.88
# type  Tensor("Shape_638:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  Tensor("test_6/Mean:0", shape=TensorShape([]), dtype=float32)
# step 2100, training accuracy 0.83
# type  Tensor("Shape_639:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  Tensor("test_6/Mean:0", shape=TensorShape([]), dtype=float32)
# step 2200, training accuracy 0.84
# type  Tensor("Shape_640:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  Tensor("test_6/Mean:0", shape=TensorShape([]), dtype=float32)
# step 2300, training accuracy 0.85
# type  Tensor("Shape_641:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  Tensor("test_6/Mean:0", shape=TensorShape([]), dtype=float32)
# step 2400, training accuracy 0.9
# type  Tensor("Shape_642:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  Tensor("test_6/Mean:0", shape=TensorShape([]), dtype=float32)
# step 2500, training accuracy 0.82
# type  Tensor("Shape_643:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  Tensor("test_6/Mean:0", shape=TensorShape([]), dtype=float32)
# step 2600, training accuracy 0.81
# type  Tensor("Shape_644:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  Tensor("test_6/Mean:0", shape=TensorShape([]), dtype=float32)
# step 2700, training accuracy 0.85
# type  Tensor("Shape_645:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  Tensor("test_6/Mean:0", shape=TensorShape([]), dtype=float32)
# step 2800, training accuracy 0.92
# type  Tensor("Shape_646:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  Tensor("test_6/Mean:0", shape=TensorShape([]), dtype=float32)
# step 2900, training accuracy 0.91
# type  Tensor("Shape_647:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  Tensor("test_6/Mean:0", shape=TensorShape([]), dtype=float32)
# step 3000, training accuracy 0.87
# type  Tensor("Shape_648:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  Tensor("test_6/Mean:0", shape=TensorShape([]), dtype=float32)
# step 3100, training accuracy 0.85
# type  Tensor("Shape_649:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  Tensor("test_6/Mean:0", shape=TensorShape([]), dtype=float32)
# step 3200, training accuracy 0.85
# type  Tensor("Shape_650:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  Tensor("test_6/Mean:0", shape=TensorShape([]), dtype=float32)
# step 3300, training accuracy 0.86
# type  Tensor("Shape_651:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  Tensor("test_6/Mean:0", shape=TensorShape([]), dtype=float32)
# step 3400, training accuracy 0.85
# type  Tensor("Shape_652:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  Tensor("test_6/Mean:0", shape=TensorShape([]), dtype=float32)
# step 3500, training accuracy 0.89
# type  Tensor("Shape_653:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  Tensor("test_6/Mean:0", shape=TensorShape([]), dtype=float32)
# step 3600, training accuracy 0.83
# type  Tensor("Shape_654:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  Tensor("test_6/Mean:0", shape=TensorShape([]), dtype=float32)
# step 3700, training accuracy 0.85
# type  Tensor("Shape_655:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  Tensor("test_6/Mean:0", shape=TensorShape([]), dtype=float32)
# step 3800, training accuracy 0.83
# type  Tensor("Shape_656:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  Tensor("test_6/Mean:0", shape=TensorShape([]), dtype=float32)
# step 3900, training accuracy 0.89
# type  Tensor("Shape_657:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  Tensor("test_6/Mean:0", shape=TensorShape([]), dtype=float32)
# step 4000, training accuracy 0.87
# type  Tensor("Shape_658:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  Tensor("test_6/Mean:0", shape=TensorShape([]), dtype=float32)
# step 4100, training accuracy 0.86
# type  Tensor("Shape_659:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  Tensor("test_6/Mean:0", shape=TensorShape([]), dtype=float32)
# step 4200, training accuracy 0.88
# type  Tensor("Shape_660:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  Tensor("test_6/Mean:0", shape=TensorShape([]), dtype=float32)
# step 4300, training accuracy 0.86
# type  Tensor("Shape_661:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  Tensor("test_6/Mean:0", shape=TensorShape([]), dtype=float32)
# step 4400, training accuracy 0.79
# type  Tensor("Shape_662:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  Tensor("test_6/Mean:0", shape=TensorShape([]), dtype=float32)
# step 4500, training accuracy 0.9
# type  Tensor("Shape_663:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  Tensor("test_6/Mean:0", shape=TensorShape([]), dtype=float32)
# step 4600, training accuracy 0.87
# type  Tensor("Shape_664:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  Tensor("test_6/Mean:0", shape=TensorShape([]), dtype=float32)
# step 4700, training accuracy 0.83
# type  Tensor("Shape_665:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  Tensor("test_6/Mean:0", shape=TensorShape([]), dtype=float32)
# step 4800, training accuracy 0.87
# type  Tensor("Shape_666:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  Tensor("test_6/Mean:0", shape=TensorShape([]), dtype=float32)
# step 4900, training accuracy 0.87
# type  Tensor("Shape_667:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  Tensor("test_6/Mean:0", shape=TensorShape([]), dtype=float32)
# step 5000, training accuracy 0.84
# type  Tensor("Shape_668:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  Tensor("test_6/Mean:0", shape=TensorShape([]), dtype=float32)
# step 5100, training accuracy 0.86
# type  Tensor("Shape_669:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  Tensor("test_6/Mean:0", shape=TensorShape([]), dtype=float32)
# step 5200, training accuracy 0.89
# type  Tensor("Shape_670:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  Tensor("test_6/Mean:0", shape=TensorShape([]), dtype=float32)
# step 5300, training accuracy 0.83
# type  Tensor("Shape_671:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  Tensor("test_6/Mean:0", shape=TensorShape([]), dtype=float32)
# step 5400, training accuracy 0.87
# type  Tensor("Shape_672:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  Tensor("test_6/Mean:0", shape=TensorShape([]), dtype=float32)
# step 5500, training accuracy 0.84
# type  Tensor("Shape_673:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  Tensor("test_6/Mean:0", shape=TensorShape([]), dtype=float32)
# step 5600, training accuracy 0.8
# type  Tensor("Shape_674:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  Tensor("test_6/Mean:0", shape=TensorShape([]), dtype=float32)
# step 5700, training accuracy 0.83
# type  Tensor("Shape_675:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  Tensor("test_6/Mean:0", shape=TensorShape([]), dtype=float32)
# step 5800, training accuracy 0.84
# type  Tensor("Shape_676:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  Tensor("test_6/Mean:0", shape=TensorShape([]), dtype=float32)
# step 5900, training accuracy 0.85
# type  Tensor("Shape_677:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  Tensor("test_6/Mean:0", shape=TensorShape([]), dtype=float32)
# step 6000, training accuracy 0.82
# type  Tensor("Shape_678:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  Tensor("test_6/Mean:0", shape=TensorShape([]), dtype=float32)
# step 6100, training accuracy 0.81
# type  Tensor("Shape_679:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  Tensor("test_6/Mean:0", shape=TensorShape([]), dtype=float32)
# step 6200, training accuracy 0.76
# type  Tensor("Shape_680:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  Tensor("test_6/Mean:0", shape=TensorShape([]), dtype=float32)
# step 6300, training accuracy 0.86
# type  Tensor("Shape_681:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  Tensor("test_6/Mean:0", shape=TensorShape([]), dtype=float32)
# step 6400, training accuracy 0.79
# type  Tensor("Shape_682:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  Tensor("test_6/Mean:0", shape=TensorShape([]), dtype=float32)
# step 6500, training accuracy 0.84
# type  Tensor("Shape_683:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  Tensor("test_6/Mean:0", shape=TensorShape([]), dtype=float32)
# step 6600, training accuracy 0.85
# type  Tensor("Shape_684:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  Tensor("test_6/Mean:0", shape=TensorShape([]), dtype=float32)
# step 6700, training accuracy 0.82
# type  Tensor("Shape_685:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  Tensor("test_6/Mean:0", shape=TensorShape([]), dtype=float32)
# step 6800, training accuracy 0.83
# type  Tensor("Shape_686:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  Tensor("test_6/Mean:0", shape=TensorShape([]), dtype=float32)
# step 6900, training accuracy 0.87
# type  Tensor("Shape_687:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  Tensor("test_6/Mean:0", shape=TensorShape([]), dtype=float32)
# step 7000, training accuracy 0.84
# type  Tensor("Shape_688:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  Tensor("test_6/Mean:0", shape=TensorShape([]), dtype=float32)
# step 7100, training accuracy 0.87
# type  Tensor("Shape_689:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  Tensor("test_6/Mean:0", shape=TensorShape([]), dtype=float32)
# step 7200, training accuracy 0.89
# type  Tensor("Shape_690:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  Tensor("test_6/Mean:0", shape=TensorShape([]), dtype=float32)
# step 7300, training accuracy 0.81
# type  Tensor("Shape_691:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  Tensor("test_6/Mean:0", shape=TensorShape([]), dtype=float32)
# step 7400, training accuracy 0.82
# type  Tensor("Shape_692:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  Tensor("test_6/Mean:0", shape=TensorShape([]), dtype=float32)
# step 7500, training accuracy 0.9
# type  Tensor("Shape_693:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  Tensor("test_6/Mean:0", shape=TensorShape([]), dtype=float32)
# step 7600, training accuracy 0.89
# type  Tensor("Shape_694:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  Tensor("test_6/Mean:0", shape=TensorShape([]), dtype=float32)
# step 7700, training accuracy 0.83
# type  Tensor("Shape_695:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  Tensor("test_6/Mean:0", shape=TensorShape([]), dtype=float32)
# step 7800, training accuracy 0.88
# type  Tensor("Shape_696:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  Tensor("test_6/Mean:0", shape=TensorShape([]), dtype=float32)
# step 7900, training accuracy 0.88
# type  Tensor("Shape_697:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  Tensor("test_6/Mean:0", shape=TensorShape([]), dtype=float32)
# step 8000, training accuracy 0.89
# type  Tensor("Shape_698:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  Tensor("test_6/Mean:0", shape=TensorShape([]), dtype=float32)
# step 8100, training accuracy 0.89
# type  Tensor("Shape_699:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  Tensor("test_6/Mean:0", shape=TensorShape([]), dtype=float32)
# step 8200, training accuracy 0.8
# type  Tensor("Shape_700:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  Tensor("test_6/Mean:0", shape=TensorShape([]), dtype=float32)
# step 8300, training accuracy 0.84
# type  Tensor("Shape_701:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  Tensor("test_6/Mean:0", shape=TensorShape([]), dtype=float32)
# step 8400, training accuracy 0.85
# type  Tensor("Shape_702:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  Tensor("test_6/Mean:0", shape=TensorShape([]), dtype=float32)
# step 8500, training accuracy 0.81
# type  Tensor("Shape_703:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  Tensor("test_6/Mean:0", shape=TensorShape([]), dtype=float32)
# step 8600, training accuracy 0.84
# type  Tensor("Shape_704:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  Tensor("test_6/Mean:0", shape=TensorShape([]), dtype=float32)
# step 8700, training accuracy 0.86
# type  Tensor("Shape_705:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  Tensor("test_6/Mean:0", shape=TensorShape([]), dtype=float32)
# step 8800, training accuracy 0.86
# type  Tensor("Shape_706:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  Tensor("test_6/Mean:0", shape=TensorShape([]), dtype=float32)
# step 8900, training accuracy 0.87
# type  Tensor("Shape_707:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  Tensor("test_6/Mean:0", shape=TensorShape([]), dtype=float32)
# step 9000, training accuracy 0.82
# type  Tensor("Shape_708:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  Tensor("test_6/Mean:0", shape=TensorShape([]), dtype=float32)
# step 9100, training accuracy 0.8
# type  Tensor("Shape_709:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  Tensor("test_6/Mean:0", shape=TensorShape([]), dtype=float32)
# step 9200, training accuracy 0.87
# type  Tensor("Shape_710:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  Tensor("test_6/Mean:0", shape=TensorShape([]), dtype=float32)
# step 9300, training accuracy 0.84
# type  Tensor("Shape_711:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  Tensor("test_6/Mean:0", shape=TensorShape([]), dtype=float32)
# step 9400, training accuracy 0.88
# type  Tensor("Shape_712:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  Tensor("test_6/Mean:0", shape=TensorShape([]), dtype=float32)
# step 9500, training accuracy 0.84
# type  Tensor("Shape_713:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  Tensor("test_6/Mean:0", shape=TensorShape([]), dtype=float32)
# step 9600, training accuracy 0.87
# type  Tensor("Shape_714:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  Tensor("test_6/Mean:0", shape=TensorShape([]), dtype=float32)
# step 9700, training accuracy 0.83
# type  Tensor("Shape_715:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  Tensor("test_6/Mean:0", shape=TensorShape([]), dtype=float32)
# step 9800, training accuracy 0.82
# type  Tensor("Shape_716:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  Tensor("test_6/Mean:0", shape=TensorShape([]), dtype=float32)
# step 9900, training accuracy 0.83

# %%
  
    
# test_xs,test_ys = testingDataLoader(category,my_testing)
print sess.run(accuracy, feed_dict={x: test_xs, y_: test_ys})
# Out:
# 0.792079

# %%
# https://github.com/tensorflow/tensorflow/issues/97
