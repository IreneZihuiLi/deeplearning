# %%
import tensorflow as tf
import numpy as np
import random
import matplotlib.pyplot as plt

from numpy import genfromtxt




# # convert ndarray to tensor
def to_tensor(arg):
  arg = tf.convert_to_tensor(arg, dtype=tf.float32)
  sess=tf.InteractiveSession()
  print arg.eval()
  return arg

# Load in training and testing data
# Shape of (record_num, col_num): (999,7)
my_data = genfromtxt('Data/s10_s23_train_data.csv', delimiter=',')
my_testing = genfromtxt('Data/s10_s23_test_data.csv', delimiter=',')

category = 10
factor = 5
sim = 0.1

# %%
# batch function
def my_batch(category,num,my_data):
#     choose a num of batch return x, y as vectors
    size,col = my_data.shape
    idList = random.sample(range(0, size), num )
    batch_xs = np.zeros(shape=(num,col-category))
    batch_ys = np.zeros(shape=(num,category))
    
    for index,i in enumerate(idList):
        line = my_data[i,:-category]
        batch_xs[index]=line
        label = my_data[i,col-category:col]
        batch_ys[index]=label
    return batch_xs,batch_ys
    
def testingDataLoader(category,my_data):
    size,col = my_data.shape
    
    batch_xs = np.zeros(shape=(size,col-category))
    batch_ys = np.zeros(shape=(size,category))
    for index,line in enumerate(my_data):
        batch_xs[index]=line[:-category]
        batch_ys[index]=line[col-category:col]

        
    return batch_xs,batch_ys

# %%
# def compare(x, y, name=None):
# #     sess=tf.InteractiveSession()
# #     sess.run(x)
# #     sess.run(y)  
#     a = tf.reshape(x,[-1]).eval()
#     b = tf.reshape(y,[-1]).eval()
# #       print a
# #       print b
#     sum = abs(np.dot(a,b))
#     cos = sum/(LA.norm(a)*LA.norm(b))
# #        print "cos",cos
#     return to_tensor(cos)

def compare(x,y,name=None):
#     sess=tf.InteractiveSession()

    norm1= tf.sqrt(tf.reduce_sum(tf.square(x),keep_dims=True))
    norm2= tf.sqrt(tf.reduce_sum(tf.square(y),keep_dims=True))
    dot = tf.reduce_sum(tf.mul(x,y))
#     print "1",norm1
#     print "2",norm2
#     print dot
    cos = abs(dot)/tf.mul(norm1,norm2)
    
#     print "cos",type(cos)
#     print "change",type(to_tensor(cos[0]))
#     return tf.convert_to_tensor(cos_, dtype=tf.float32)
    return cos

# %%
# Implementation starts!

# None means any number, so x is not a specific number here.
x = tf.placeholder(tf.float32, [None, factor],name="x-input")


# In[16]:

# Init weights, bias, (all zeros first) and define softmax function
W = tf.Variable(tf.zeros([factor, category]),name="weights")
b = tf.Variable(tf.zeros([category],name="bias"))

# use a name scope to organize nodes in the graph visualizer
with tf.name_scope("Wx_b") as scope:
# first multiply x and w, then add b vector. apply softmax to get probabilities
#   y = tf.nn.softmax(tf.matmul(x, W) + b)
    y = tf.matmul(x, W) + b
print "y",type(y)

# Add summary ops to collect data
w_hist = tf.histogram_summary("weights", W)
b_hist = tf.histogram_summary("biases", b)
y_hist = tf.histogram_summary("y", y)


weights_summary = tf.histogram_summary("weights", W)
biases_summary = tf.histogram_summary("biases", b)
y_summary = tf.histogram_summary("y", y)


# In[20]:

# Trainning
y_ = tf.placeholder(tf.float32, [None, category],name="y-input")

with tf.name_scope("xent") as scope:
# tf.log computes logarithm of each element. 
  cross_entropy = -tf.reduce_sum(y_*tf.log(y))
    
with tf.name_scope("train") as scope:
# minimize cross_entropy using the gradient descent algorithm with a learning rate of 0.01. 
  train_step = tf.train.GradientDescentOptimizer(0.0001).minimize(cross_entropy)


# In[21]:
# Out:
# y <class 'tensorflow.python.framework.ops.Tensor'>

# %%
# In[22]:


  
  
init = tf.initialize_all_variables()

# launch the model in a Session, run the initialized operation
sess = tf.Session()
sess.run(init)



  
# Merge all the summaries and write them out to /tmp/mnist_logs
merged = tf.merge_summary([weights_summary, biases_summary, y_summary])
writer = tf.train.SummaryWriter("/tmp/read2", sess.graph_def)
tf.train.SummaryWriter("/tmp/read2", sess.graph_def).flush()
# tf.train.SummaryWriter.flush()

# %%
with tf.name_scope("test") as scope:
# evaluation
#   correct_prediction = tf.equal(tf.argmax(y,1), tf.argmax(y_,1))   -> [T,F,T,T...]
#   accuracy = tf.reduce_mean(tf.cast(correct_prediction, "float"))
    norm1= tf.sqrt(tf.reduce_sum(tf.square(y),keep_dims=True))
    norm2= tf.sqrt(tf.reduce_sum(tf.square(y_),keep_dims=True))
    dot = tf.reduce_sum(tf.mul(y,y_))
#     print "1",norm1
#     print "2",norm2
#     print dot
    accuracy = abs(dot)/tf.mul(norm1,norm2)

    accuracy_summary = tf.scalar_summary("accuracy", accuracy)

# %%
# get testing data
test_xs,test_ys = testingDataLoader(category,my_testing)


# Train for 1000 times!
# batch of 100 at each time
# train_step feeding in the batches data to replace the placeholders
for i in range(10000):


  batch_xs, batch_ys = my_batch(category,100, my_data)
  feed = {x: batch_xs, y_: batch_ys}

  if i%100 == 0:
    train_accuracy = accuracy.eval(session=sess, feed_dict=feed)
    print "type ",tf.shape(accuracy)
    print "value ", train_accuracy
    print "step %d, training accuracy %g"%(i, train_accuracy)
  train_step.run(session=sess, feed_dict=feed)


#     batch_xs, batch_ys = my_batch(category,100, my_data)
#     feed = {x: batch_xs, y_: batch_ys}
#     sess.run(train_step, feed_dict=feed)
# Out:
# type  Tensor("Shape_934:0", shape=TensorShape([Dimension(2)]), dtype=int32)
# value  [[ nan]]
# step 0, training accuracy nan
# type  Tensor("Shape_935:0", shape=TensorShape([Dimension(2)]), dtype=int32)
# value  [[ nan]]
# step 100, training accuracy nan
# type  Tensor("Shape_936:0", shape=TensorShape([Dimension(2)]), dtype=int32)
# value  [[ nan]]
# step 200, training accuracy nan
# type  Tensor("Shape_937:0", shape=TensorShape([Dimension(2)]), dtype=int32)
# value  [[ nan]]
# step 300, training accuracy nan
# type  Tensor("Shape_938:0", shape=TensorShape([Dimension(2)]), dtype=int32)
# value  [[ nan]]
# step 400, training accuracy nan
# type  Tensor("Shape_939:0", shape=TensorShape([Dimension(2)]), dtype=int32)
# value  [[ nan]]
# step 500, training accuracy nan
# type  Tensor("Shape_940:0", shape=TensorShape([Dimension(2)]), dtype=int32)
# value  [[ nan]]
# step 600, training accuracy nan
# type  Tensor("Shape_941:0", shape=TensorShape([Dimension(2)]), dtype=int32)
# value  [[ nan]]
# step 700, training accuracy nan
# type  Tensor("Shape_942:0", shape=TensorShape([Dimension(2)]), dtype=int32)
# value  [[ nan]]
# step 800, training accuracy nan
# type  Tensor("Shape_943:0", shape=TensorShape([Dimension(2)]), dtype=int32)
# value  [[ nan]]
# step 900, training accuracy nan
# type  Tensor("Shape_944:0", shape=TensorShape([Dimension(2)]), dtype=int32)
# value  [[ nan]]
# step 1000, training accuracy nan
# type  Tensor("Shape_945:0", shape=TensorShape([Dimension(2)]), dtype=int32)
# value  [[ nan]]
# step 1100, training accuracy nan
# type  Tensor("Shape_946:0", shape=TensorShape([Dimension(2)]), dtype=int32)
# value  [[ nan]]
# step 1200, training accuracy nan
# type  Tensor("Shape_947:0", shape=TensorShape([Dimension(2)]), dtype=int32)
# value  [[ nan]]
# step 1300, training accuracy nan
# type  Tensor("Shape_948:0", shape=TensorShape([Dimension(2)]), dtype=int32)
# value  [[ nan]]
# step 1400, training accuracy nan
# type  Tensor("Shape_949:0", shape=TensorShape([Dimension(2)]), dtype=int32)
# value  [[ nan]]
# step 1500, training accuracy nan
# type  Tensor("Shape_950:0", shape=TensorShape([Dimension(2)]), dtype=int32)
# value  [[ nan]]
# step 1600, training accuracy nan
# type  Tensor("Shape_951:0", shape=TensorShape([Dimension(2)]), dtype=int32)
# value  [[ nan]]
# step 1700, training accuracy nan
# type  Tensor("Shape_952:0", shape=TensorShape([Dimension(2)]), dtype=int32)
# value  [[ nan]]
# step 1800, training accuracy nan
# type  Tensor("Shape_953:0", shape=TensorShape([Dimension(2)]), dtype=int32)
# value  [[ nan]]
# step 1900, training accuracy nan
# type  Tensor("Shape_954:0", shape=TensorShape([Dimension(2)]), dtype=int32)
# value  [[ nan]]
# step 2000, training accuracy nan
# type  Tensor("Shape_955:0", shape=TensorShape([Dimension(2)]), dtype=int32)
# value  [[ nan]]
# step 2100, training accuracy nan
# type  Tensor("Shape_956:0", shape=TensorShape([Dimension(2)]), dtype=int32)
# value  [[ nan]]
# step 2200, training accuracy nan
# type  Tensor("Shape_957:0", shape=TensorShape([Dimension(2)]), dtype=int32)
# value  [[ nan]]
# step 2300, training accuracy nan
# type  Tensor("Shape_958:0", shape=TensorShape([Dimension(2)]), dtype=int32)
# value  [[ nan]]
# step 2400, training accuracy nan
# type  Tensor("Shape_959:0", shape=TensorShape([Dimension(2)]), dtype=int32)
# value  [[ nan]]
# step 2500, training accuracy nan
# type  Tensor("Shape_960:0", shape=TensorShape([Dimension(2)]), dtype=int32)
# value  [[ nan]]
# step 2600, training accuracy nan
# type  Tensor("Shape_961:0", shape=TensorShape([Dimension(2)]), dtype=int32)
# value  [[ nan]]
# step 2700, training accuracy nan
# type  Tensor("Shape_962:0", shape=TensorShape([Dimension(2)]), dtype=int32)
# value  [[ nan]]
# step 2800, training accuracy nan
# type  Tensor("Shape_963:0", shape=TensorShape([Dimension(2)]), dtype=int32)
# value  [[ nan]]
# step 2900, training accuracy nan
# type  Tensor("Shape_964:0", shape=TensorShape([Dimension(2)]), dtype=int32)
# value  [[ nan]]
# step 3000, training accuracy nan
# type  Tensor("Shape_965:0", shape=TensorShape([Dimension(2)]), dtype=int32)
# value  [[ nan]]
# step 3100, training accuracy nan
# type  Tensor("Shape_966:0", shape=TensorShape([Dimension(2)]), dtype=int32)
# value  [[ nan]]
# step 3200, training accuracy nan
# type  Tensor("Shape_967:0", shape=TensorShape([Dimension(2)]), dtype=int32)
# value  [[ nan]]
# step 3300, training accuracy nan
# type  Tensor("Shape_968:0", shape=TensorShape([Dimension(2)]), dtype=int32)
# value  [[ nan]]
# step 3400, training accuracy nan
# type  Tensor("Shape_969:0", shape=TensorShape([Dimension(2)]), dtype=int32)
# value  [[ nan]]
# step 3500, training accuracy nan
# type  Tensor("Shape_970:0", shape=TensorShape([Dimension(2)]), dtype=int32)
# value  [[ nan]]
# step 3600, training accuracy nan
# type  Tensor("Shape_971:0", shape=TensorShape([Dimension(2)]), dtype=int32)
# value  [[ nan]]
# step 3700, training accuracy nan
# type  Tensor("Shape_972:0", shape=TensorShape([Dimension(2)]), dtype=int32)
# value  [[ nan]]
# step 3800, training accuracy nan
# type  Tensor("Shape_973:0", shape=TensorShape([Dimension(2)]), dtype=int32)
# value  [[ nan]]
# step 3900, training accuracy nan
# type  Tensor("Shape_974:0", shape=TensorShape([Dimension(2)]), dtype=int32)
# value  [[ nan]]
# step 4000, training accuracy nan
# type  Tensor("Shape_975:0", shape=TensorShape([Dimension(2)]), dtype=int32)
# value  [[ nan]]
# step 4100, training accuracy nan
# type  Tensor("Shape_976:0", shape=TensorShape([Dimension(2)]), dtype=int32)
# value  [[ nan]]
# step 4200, training accuracy nan
# type  Tensor("Shape_977:0", shape=TensorShape([Dimension(2)]), dtype=int32)
# value  [[ nan]]
# step 4300, training accuracy nan
# type  Tensor("Shape_978:0", shape=TensorShape([Dimension(2)]), dtype=int32)
# value  [[ nan]]
# step 4400, training accuracy nan
# type  Tensor("Shape_979:0", shape=TensorShape([Dimension(2)]), dtype=int32)
# value  [[ nan]]
# step 4500, training accuracy nan
# type  Tensor("Shape_980:0", shape=TensorShape([Dimension(2)]), dtype=int32)
# value  [[ nan]]
# step 4600, training accuracy nan
# type  Tensor("Shape_981:0", shape=TensorShape([Dimension(2)]), dtype=int32)
# value  [[ nan]]
# step 4700, training accuracy nan
# type  Tensor("Shape_982:0", shape=TensorShape([Dimension(2)]), dtype=int32)
# value  [[ nan]]
# step 4800, training accuracy nan
# type  Tensor("Shape_983:0", shape=TensorShape([Dimension(2)]), dtype=int32)
# value  [[ nan]]
# step 4900, training accuracy nan
# type  Tensor("Shape_984:0", shape=TensorShape([Dimension(2)]), dtype=int32)
# value  [[ nan]]
# step 5000, training accuracy nan
# type  Tensor("Shape_985:0", shape=TensorShape([Dimension(2)]), dtype=int32)
# value  [[ nan]]
# step 5100, training accuracy nan
# type  Tensor("Shape_986:0", shape=TensorShape([Dimension(2)]), dtype=int32)
# value  [[ nan]]
# step 5200, training accuracy nan
# type  Tensor("Shape_987:0", shape=TensorShape([Dimension(2)]), dtype=int32)
# value  [[ nan]]
# step 5300, training accuracy nan
# type  Tensor("Shape_988:0", shape=TensorShape([Dimension(2)]), dtype=int32)
# value  [[ nan]]
# step 5400, training accuracy nan
# type  Tensor("Shape_989:0", shape=TensorShape([Dimension(2)]), dtype=int32)
# value  [[ nan]]
# step 5500, training accuracy nan
# type  Tensor("Shape_990:0", shape=TensorShape([Dimension(2)]), dtype=int32)
# value  [[ nan]]
# step 5600, training accuracy nan
# type  Tensor("Shape_991:0", shape=TensorShape([Dimension(2)]), dtype=int32)
# value  [[ nan]]
# step 5700, training accuracy nan
# type  Tensor("Shape_992:0", shape=TensorShape([Dimension(2)]), dtype=int32)
# value  [[ nan]]
# step 5800, training accuracy nan
# type  Tensor("Shape_993:0", shape=TensorShape([Dimension(2)]), dtype=int32)
# value  [[ nan]]
# step 5900, training accuracy nan
# type  Tensor("Shape_994:0", shape=TensorShape([Dimension(2)]), dtype=int32)
# value  [[ nan]]
# step 6000, training accuracy nan
# type  Tensor("Shape_995:0", shape=TensorShape([Dimension(2)]), dtype=int32)
# value  [[ nan]]
# step 6100, training accuracy nan
# type  Tensor("Shape_996:0", shape=TensorShape([Dimension(2)]), dtype=int32)
# value  [[ nan]]
# step 6200, training accuracy nan
# type  Tensor("Shape_997:0", shape=TensorShape([Dimension(2)]), dtype=int32)
# value  [[ nan]]
# step 6300, training accuracy nan
# type  Tensor("Shape_998:0", shape=TensorShape([Dimension(2)]), dtype=int32)
# value  [[ nan]]
# step 6400, training accuracy nan
# type  Tensor("Shape_999:0", shape=TensorShape([Dimension(2)]), dtype=int32)
# value  [[ nan]]
# step 6500, training accuracy nan
# type  Tensor("Shape_1000:0", shape=TensorShape([Dimension(2)]), dtype=int32)
# value  [[ nan]]
# step 6600, training accuracy nan
# type  Tensor("Shape_1001:0", shape=TensorShape([Dimension(2)]), dtype=int32)
# value  [[ nan]]
# step 6700, training accuracy nan
# type  Tensor("Shape_1002:0", shape=TensorShape([Dimension(2)]), dtype=int32)
# value  [[ nan]]
# step 6800, training accuracy nan
# type  Tensor("Shape_1003:0", shape=TensorShape([Dimension(2)]), dtype=int32)
# value  [[ nan]]
# step 6900, training accuracy nan
# type  Tensor("Shape_1004:0", shape=TensorShape([Dimension(2)]), dtype=int32)
# value  [[ nan]]
# step 7000, training accuracy nan
# type  Tensor("Shape_1005:0", shape=TensorShape([Dimension(2)]), dtype=int32)
# value  [[ nan]]
# step 7100, training accuracy nan
# type  Tensor("Shape_1006:0", shape=TensorShape([Dimension(2)]), dtype=int32)
# value  [[ nan]]
# step 7200, training accuracy nan
# type  Tensor("Shape_1007:0", shape=TensorShape([Dimension(2)]), dtype=int32)
# value  [[ nan]]
# step 7300, training accuracy nan
# type  Tensor("Shape_1008:0", shape=TensorShape([Dimension(2)]), dtype=int32)
# value  [[ nan]]
# step 7400, training accuracy nan
# type  Tensor("Shape_1009:0", shape=TensorShape([Dimension(2)]), dtype=int32)
# value  [[ nan]]
# step 7500, training accuracy nan
# type  Tensor("Shape_1010:0", shape=TensorShape([Dimension(2)]), dtype=int32)
# value  [[ nan]]
# step 7600, training accuracy nan
# type  Tensor("Shape_1011:0", shape=TensorShape([Dimension(2)]), dtype=int32)
# value  [[ nan]]
# step 7700, training accuracy nan
# type  Tensor("Shape_1012:0", shape=TensorShape([Dimension(2)]), dtype=int32)
# value  [[ nan]]
# step 7800, training accuracy nan
# type  Tensor("Shape_1013:0", shape=TensorShape([Dimension(2)]), dtype=int32)
# value  [[ nan]]
# step 7900, training accuracy nan
# type  Tensor("Shape_1014:0", shape=TensorShape([Dimension(2)]), dtype=int32)
# value  [[ nan]]
# step 8000, training accuracy nan
# type  Tensor("Shape_1015:0", shape=TensorShape([Dimension(2)]), dtype=int32)
# value  [[ nan]]
# step 8100, training accuracy nan
# type  Tensor("Shape_1016:0", shape=TensorShape([Dimension(2)]), dtype=int32)
# value  [[ nan]]
# step 8200, training accuracy nan
# type  Tensor("Shape_1017:0", shape=TensorShape([Dimension(2)]), dtype=int32)
# value  [[ nan]]
# step 8300, training accuracy nan
# type  Tensor("Shape_1018:0", shape=TensorShape([Dimension(2)]), dtype=int32)
# value  [[ nan]]
# step 8400, training accuracy nan
# type  Tensor("Shape_1019:0", shape=TensorShape([Dimension(2)]), dtype=int32)
# value  [[ nan]]
# step 8500, training accuracy nan
# type  Tensor("Shape_1020:0", shape=TensorShape([Dimension(2)]), dtype=int32)
# value  [[ nan]]
# step 8600, training accuracy nan
# type  Tensor("Shape_1021:0", shape=TensorShape([Dimension(2)]), dtype=int32)
# value  [[ nan]]
# step 8700, training accuracy nan
# type  Tensor("Shape_1022:0", shape=TensorShape([Dimension(2)]), dtype=int32)
# value  [[ nan]]
# step 8800, training accuracy nan
# type  Tensor("Shape_1023:0", shape=TensorShape([Dimension(2)]), dtype=int32)
# value  [[ nan]]
# step 8900, training accuracy nan
# type  Tensor("Shape_1024:0", shape=TensorShape([Dimension(2)]), dtype=int32)
# value  [[ nan]]
# step 9000, training accuracy nan
# type  Tensor("Shape_1025:0", shape=TensorShape([Dimension(2)]), dtype=int32)
# value  [[ nan]]
# step 9100, training accuracy nan
# type  Tensor("Shape_1026:0", shape=TensorShape([Dimension(2)]), dtype=int32)
# value  [[ nan]]
# step 9200, training accuracy nan
# type  Tensor("Shape_1027:0", shape=TensorShape([Dimension(2)]), dtype=int32)
# value  [[ nan]]
# step 9300, training accuracy nan
# type  Tensor("Shape_1028:0", shape=TensorShape([Dimension(2)]), dtype=int32)
# value  [[ nan]]
# step 9400, training accuracy nan
# type  Tensor("Shape_1029:0", shape=TensorShape([Dimension(2)]), dtype=int32)
# value  [[ nan]]
# step 9500, training accuracy nan
# type  Tensor("Shape_1030:0", shape=TensorShape([Dimension(2)]), dtype=int32)
# value  [[ nan]]
# step 9600, training accuracy nan
# type  Tensor("Shape_1031:0", shape=TensorShape([Dimension(2)]), dtype=int32)
# value  [[ nan]]
# step 9700, training accuracy nan
# type  Tensor("Shape_1032:0", shape=TensorShape([Dimension(2)]), dtype=int32)
# value  [[ nan]]
# step 9800, training accuracy nan
# type  Tensor("Shape_1033:0", shape=TensorShape([Dimension(2)]), dtype=int32)
# value  [[ nan]]
# step 9900, training accuracy nan

# %%
  
    
# test_xs,test_ys = testingDataLoader(category,my_testing)
print sess.run(accuracy, feed_dict={x: test_xs, y_: test_ys})
# Out:
# [[ nan]]
