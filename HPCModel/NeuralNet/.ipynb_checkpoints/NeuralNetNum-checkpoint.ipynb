# %%
import tensorflow as tf
import numpy as np
import random
import matplotlib.pyplot as plt

from numpy import genfromtxt


# Load in training and testing data
# Shape of (record_num, col_num): (999,7)
my_data = genfromtxt('Data/modelData.csv', delimiter=',')
my_testing = genfromtxt('Data/testData.csv', delimiter=',')

category = 5

factor = 1

# %%
# batch function
def my_batch(category,num,my_data):
#     choose a num of batch return x, y as vectors
    size,col = my_data.shape
    idList = random.sample(range(0, size), num )
    batch_xs = np.zeros(shape=(num,col-category))
    batch_ys = np.zeros(shape=(num,category))
    
    for index,i in enumerate(idList):
        line = my_data[i,:-category]
        batch_xs[index]=line
        label = my_data[i,col-category:col]
        batch_ys[index]=label
    return batch_xs,batch_ys
    
def testingDataLoader(category,my_data):
    size,col = my_data.shape
    
    batch_xs = np.zeros(shape=(size,col-category))
    batch_ys = np.zeros(shape=(size,category))
    for index,line in enumerate(my_data):
        batch_xs[index]=line[:-category]
        batch_ys[index]=line[col-category:col]

        
    return batch_xs,batch_ys

# %%
# Implementation starts!

# None means any number, so x is not a specific number here.
x = tf.placeholder(tf.float32, [None, factor],name="x-input")


# In[16]:

# Init weights, bias, (all zeros first) and define softmax function
W = tf.Variable(tf.zeros([factor, category]),name="weights")
b = tf.Variable(tf.zeros([category],name="bias"))

# use a name scope to organize nodes in the graph visualizer
with tf.name_scope("Wx_b") as scope:
# first multiply x and w, then add b vector. apply softmax to get probabilities
#   y = tf.nn.softmax(tf.matmul(x, W) + b)
    y = tf.matmul(x, W) + b
print "y",type(y)

# Add summary ops to collect data
w_hist = tf.histogram_summary("weights", W)
b_hist = tf.histogram_summary("biases", b)
y_hist = tf.histogram_summary("y", y)


weights_summary = tf.histogram_summary("weights", W)
biases_summary = tf.histogram_summary("biases", b)
y_summary = tf.histogram_summary("y", y)


# In[20]:

# Trainning
y_ = tf.placeholder(tf.float32, [None, category],name="y-input")

with tf.name_scope("xent") as scope:
# tf.log computes logarithm of each element. 
#   cross_entropy = -tf.reduce_sum(y_*tf.log(y))
      cross_entropy = -tf.reduce_sum(tf.mul(y_,y))

with tf.name_scope("train") as scope:
# minimize cross_entropy using the gradient descent algorithm with a learning rate of 0.01. 
  train_step = tf.train.GradientDescentOptimizer(0.001).minimize(cross_entropy)


# In[21]:
# Out:
# y <class 'tensorflow.python.framework.ops.Tensor'>

# %%
# In[22]:

with tf.name_scope("test") as scope:
# evaluation
    y_shaped = tf.reshape(y,[-1])
    y__shaped = tf.reshape(y_,[-1])
    norm1= tf.sqrt(tf.reduce_sum(tf.square(y_shaped),keep_dims=True))
    norm2= tf.sqrt(tf.reduce_sum(tf.square(y__shaped),keep_dims=True))
    dot = tf.reduce_sum(tf.mul(y_shaped,y__shaped))
    cos = abs(dot)/tf.mul(norm1,norm2)
    accuracy = tf.reduce_sum(cos)

#     accuracy = tf.reduce_sum(y)

#   correct_prediction = tf.equal(tf.argmax(y,1), tf.argmax(y_,1))
#   accuracy = tf.reduce_mean(tf.cast(correct_prediction, "float"))
#   accuracy_summary = tf.scalar_summary("accuracy", accuracy)

  
  
init = tf.initialize_all_variables()

# launch the model in a Session, run the initialized operation
sess = tf.Session()
sess.run(init)


  
# Merge all the summaries and write them out to /tmp/mnist_logs
merged = tf.merge_summary([weights_summary, biases_summary, y_summary])
writer = tf.train.SummaryWriter("/tmp/read2", sess.graph_def)
tf.train.SummaryWriter("/tmp/read2", sess.graph_def).flush()
# tf.train.SummaryWriter.flush()

# %%
# get testing data
test_xs,test_ys = testingDataLoader(category,my_testing)


# Train for 1000 times!
# batch of 100 at each time
# train_step feeding in the batches data to replace the placeholders
for i in range(10000):


  batch_xs, batch_ys = my_batch(category,100, my_data)
  feed = {x: batch_xs, y_: batch_ys}

  if i%100 == 0:
    train_accuracy = accuracy.eval(session=sess, feed_dict=feed)
    print "type ",tf.shape(accuracy)
    print "value ",train_accuracy
    print "step %d, training accuracy %g"%(i, train_accuracy)
  train_step.run(session=sess, feed_dict=feed)


#     batch_xs, batch_ys = my_batch(category,100, my_data)
#     feed = {x: batch_xs, y_: batch_ys}
#     sess.run(train_step, feed_dict=feed)
# Out:
# type  Tensor("Shape_511:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  nan
# step 0, training accuracy nan
# type  Tensor("Shape_512:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  0.706021
# step 100, training accuracy 0.706021
# type  Tensor("Shape_513:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  0.721984
# step 200, training accuracy 0.721984
# type  Tensor("Shape_514:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  0.770838
# step 300, training accuracy 0.770838
# type  Tensor("Shape_515:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  0.727211
# step 400, training accuracy 0.727211
# type  Tensor("Shape_516:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  0.748983
# step 500, training accuracy 0.748983
# type  Tensor("Shape_517:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  0.779709
# step 600, training accuracy 0.779709
# type  Tensor("Shape_518:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  0.733687
# step 700, training accuracy 0.733687
# type  Tensor("Shape_519:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  0.74204
# step 800, training accuracy 0.74204
# type  Tensor("Shape_520:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  0.754171
# step 900, training accuracy 0.754171
# type  Tensor("Shape_521:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  0.709133
# step 1000, training accuracy 0.709133
# type  Tensor("Shape_522:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  0.697748
# step 1100, training accuracy 0.697748
# type  Tensor("Shape_523:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  0.727749
# step 1200, training accuracy 0.727749
# type  Tensor("Shape_524:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  0.732652
# step 1300, training accuracy 0.732652
# type  Tensor("Shape_525:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  0.702074
# step 1400, training accuracy 0.702074
# type  Tensor("Shape_526:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  0.748932
# step 1500, training accuracy 0.748932
# type  Tensor("Shape_527:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  0.726797
# step 1600, training accuracy 0.726797
# type  Tensor("Shape_528:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  0.772422
# step 1700, training accuracy 0.772422
# type  Tensor("Shape_529:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  0.761018
# step 1800, training accuracy 0.761018
# type  Tensor("Shape_530:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  0.719781
# step 1900, training accuracy 0.719781
# type  Tensor("Shape_531:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  0.746246
# step 2000, training accuracy 0.746246
# type  Tensor("Shape_532:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  0.723573
# step 2100, training accuracy 0.723573
# type  Tensor("Shape_533:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  0.7166
# step 2200, training accuracy 0.7166
# type  Tensor("Shape_534:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  0.728079
# step 2300, training accuracy 0.728079
# type  Tensor("Shape_535:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  0.718961
# step 2400, training accuracy 0.718961
# type  Tensor("Shape_536:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  0.755936
# step 2500, training accuracy 0.755936
# type  Tensor("Shape_537:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  0.730391
# step 2600, training accuracy 0.730391
# type  Tensor("Shape_538:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  0.768352
# step 2700, training accuracy 0.768352
# type  Tensor("Shape_539:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  0.750107
# step 2800, training accuracy 0.750107
# type  Tensor("Shape_540:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  0.737054
# step 2900, training accuracy 0.737054
# type  Tensor("Shape_541:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  0.75375
# step 3000, training accuracy 0.75375
# type  Tensor("Shape_542:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  0.722841
# step 3100, training accuracy 0.722841
# type  Tensor("Shape_543:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  0.709758
# step 3200, training accuracy 0.709758
# type  Tensor("Shape_544:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  0.713185
# step 3300, training accuracy 0.713185
# type  Tensor("Shape_545:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  0.711666
# step 3400, training accuracy 0.711666
# type  Tensor("Shape_546:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  0.728028
# step 3500, training accuracy 0.728028
# type  Tensor("Shape_547:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  0.7345
# step 3600, training accuracy 0.7345
# type  Tensor("Shape_548:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  0.739734
# step 3700, training accuracy 0.739734
# type  Tensor("Shape_549:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  0.721991
# step 3800, training accuracy 0.721991
# type  Tensor("Shape_550:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  0.738916
# step 3900, training accuracy 0.738916
# type  Tensor("Shape_551:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  0.747681
# step 4000, training accuracy 0.747681
# type  Tensor("Shape_552:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  0.740336
# step 4100, training accuracy 0.740336
# type  Tensor("Shape_553:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  0.735461
# step 4200, training accuracy 0.735461
# type  Tensor("Shape_554:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  0.77445
# step 4300, training accuracy 0.77445
# type  Tensor("Shape_555:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  0.744255
# step 4400, training accuracy 0.744255
# type  Tensor("Shape_556:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  0.72961
# step 4500, training accuracy 0.72961
# type  Tensor("Shape_557:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  0.691972
# step 4600, training accuracy 0.691972
# type  Tensor("Shape_558:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  0.70156
# step 4700, training accuracy 0.70156
# type  Tensor("Shape_559:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  0.765475
# step 4800, training accuracy 0.765475
# type  Tensor("Shape_560:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  0.734299
# step 4900, training accuracy 0.734299
# type  Tensor("Shape_561:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  0.709841
# step 5000, training accuracy 0.709841
# type  Tensor("Shape_562:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  0.779608
# step 5100, training accuracy 0.779608
# type  Tensor("Shape_563:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  0.778584
# step 5200, training accuracy 0.778584
# type  Tensor("Shape_564:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  0.769925
# step 5300, training accuracy 0.769925
# type  Tensor("Shape_565:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  0.795422
# step 5400, training accuracy 0.795422
# type  Tensor("Shape_566:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  0.690752
# step 5500, training accuracy 0.690752
# type  Tensor("Shape_567:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  0.712167
# step 5600, training accuracy 0.712167
# type  Tensor("Shape_568:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  0.737231
# step 5700, training accuracy 0.737231
# type  Tensor("Shape_569:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  0.728533
# step 5800, training accuracy 0.728533
# type  Tensor("Shape_570:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  0.737062
# step 5900, training accuracy 0.737062
# type  Tensor("Shape_571:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  0.768487
# step 6000, training accuracy 0.768487
# type  Tensor("Shape_572:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  0.764069
# step 6100, training accuracy 0.764069
# type  Tensor("Shape_573:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  0.707179
# step 6200, training accuracy 0.707179
# type  Tensor("Shape_574:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  0.746542
# step 6300, training accuracy 0.746542
# type  Tensor("Shape_575:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  0.723912
# step 6400, training accuracy 0.723912
# type  Tensor("Shape_576:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  0.770096
# step 6500, training accuracy 0.770096
# type  Tensor("Shape_577:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  0.693808
# step 6600, training accuracy 0.693808
# type  Tensor("Shape_578:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  0.731148
# step 6700, training accuracy 0.731148
# type  Tensor("Shape_579:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  0.728233
# step 6800, training accuracy 0.728233
# type  Tensor("Shape_580:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  0.718279
# step 6900, training accuracy 0.718279
# type  Tensor("Shape_581:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  0.743092
# step 7000, training accuracy 0.743092
# type  Tensor("Shape_582:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  0.734155
# step 7100, training accuracy 0.734155
# type  Tensor("Shape_583:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  0.739706
# step 7200, training accuracy 0.739706
# type  Tensor("Shape_584:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  0.727592
# step 7300, training accuracy 0.727592
# type  Tensor("Shape_585:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  0.756126
# step 7400, training accuracy 0.756126
# type  Tensor("Shape_586:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  0.754346
# step 7500, training accuracy 0.754346
# type  Tensor("Shape_587:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  0.729864
# step 7600, training accuracy 0.729864
# type  Tensor("Shape_588:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  0.740677
# step 7700, training accuracy 0.740677
# type  Tensor("Shape_589:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  0.719919
# step 7800, training accuracy 0.719919
# type  Tensor("Shape_590:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  0.689181
# step 7900, training accuracy 0.689181
# type  Tensor("Shape_591:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  0.714712
# step 8000, training accuracy 0.714712
# type  Tensor("Shape_592:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  0.795396
# step 8100, training accuracy 0.795396
# type  Tensor("Shape_593:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  0.699971
# step 8200, training accuracy 0.699971
# type  Tensor("Shape_594:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  0.731979
# step 8300, training accuracy 0.731979
# type  Tensor("Shape_595:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  0.755626
# step 8400, training accuracy 0.755626
# type  Tensor("Shape_596:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  0.737267
# step 8500, training accuracy 0.737267
# type  Tensor("Shape_597:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  0.791099
# step 8600, training accuracy 0.791099
# type  Tensor("Shape_598:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  0.761489
# step 8700, training accuracy 0.761489
# type  Tensor("Shape_599:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  0.783565
# step 8800, training accuracy 0.783565
# type  Tensor("Shape_600:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  0.74595
# step 8900, training accuracy 0.74595
# type  Tensor("Shape_601:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  0.79649
# step 9000, training accuracy 0.79649
# type  Tensor("Shape_602:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  0.738203
# step 9100, training accuracy 0.738203
# type  Tensor("Shape_603:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  0.738047
# step 9200, training accuracy 0.738047
# type  Tensor("Shape_604:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  0.750603
# step 9300, training accuracy 0.750603
# type  Tensor("Shape_605:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  0.769448
# step 9400, training accuracy 0.769448
# type  Tensor("Shape_606:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  0.729943
# step 9500, training accuracy 0.729943
# type  Tensor("Shape_607:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  0.730482
# step 9600, training accuracy 0.730482
# type  Tensor("Shape_608:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  0.735362
# step 9700, training accuracy 0.735362
# type  Tensor("Shape_609:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  0.743781
# step 9800, training accuracy 0.743781
# type  Tensor("Shape_610:0", shape=TensorShape([Dimension(0)]), dtype=int32)
# value  0.762925
# step 9900, training accuracy 0.762925

# %%
  
    
# test_xs,test_ys = testingDataLoader(category,my_testing)
print sess.run(accuracy, feed_dict={x: test_xs, y_: test_ys})
# Out:
# 0.738134

# %%
# https://github.com/tensorflow/tensorflow/issues/97

# %%
print sess.run(accuracy, feed_dict={x: test_xs, y_: test_ys})
# Out:
# 0.738134
